# %%
# Data manipulation
import pandas as pd
import numpy as np
import json

# Visualisation
import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.graph_objects as go

# Network
import networkx as nx

# Data preparation
# from data.data_pipeline import generate_xlsx_for_gephi
# generate_xlsx_for_gephi()

# %%
lst_every_episode = []

# %%
with open('data/Star Wars/starwars-episode-1-interactions-allCharacters.json', 'r') as file:
    data = json.load(file)

nodes = data['nodes']

df_nodes = pd.DataFrame(nodes)
df_nodes = df_nodes.reset_index(drop=False)
df_nodes1 = df_nodes.rename(columns={"index": "ID"})

df_nodes1
# Out:
#     ID            name  value   colour
# 0    0           R2-D2     33  #bde0f6
# 1    1         QUI-GON     61  #4f4fb1
# 2    2     NUTE GUNRAY     19  #808080
# 3    3            PK-4      3  #808080
# 4    4           TC-14      5  #808080
# 5    5         OBI-WAN     34  #48D1CC
# 6    6          DOFINE      4  #808080
# 7    7            RUNE     11  #808080
# 8    8         TEY HOW      5  #808080
# 9    9         EMPEROR     14  #191970
# 10  10  CAPTAIN PANAKA     20  #808080
# 11  11      SIO BIBBLE      8  #808080
# 12  12         JAR JAR     36  #9a9a00
# 13  13         TARPALS      4  #808080
# 14  14       BOSS NASS      5  #808080
# 15  15           PADME     31  #DDA0DD
# 16  16        RIC OLIE     12  #808080
# 17  17           WATTO      8  #808080
# 18  18          ANAKIN     41  #ce3b59
# 19  19         SEBULBA      4  #808080
# 20  20            JIRA      4  #808080
# 21  21            SHMI     11  #808080
# 22  22           C-3PO      6  #FFD700
# 23  23      DARTH MAUL      6  #808080
# 24  24         KITSTER      5  #808080
# 25  25            WALD      4  #808080
# 26  26       FODE/BEED     12  #808080
# 27  27           JABBA      4  #808080
# 28  28          GREEDO      3  #808080
# 29  29         VALORUM      4  #808080
# 30  30      MACE WINDU      6  #808080
# 31  31    KI-ADI-MUNDI      5  #808080
# 32  32            YODA      7  #9ACD32
# 33  33            RABE      3  #808080
# 34  34     BAIL ORGANA      3  #808080
# 35  35    GENERAL CEEL      5  #808080
# 36  36       BRAVO TWO      6  #808080
# 37  37     BRAVO THREE      4  #808080

# %%
edges = data['links']
df_edges1 = pd.DataFrame(edges)

df_edges1
# Out:
#      source  target  value
# 0        15       0     11
# 1         1       0     14
# 2        18       0     16
# 3         0      17      3
# 4        22       0      2
# ..      ...     ...    ...
# 130       6       8      1
# 131      37      36      2
# 132      37      16      2
# 133      18      37      1
# 134       9      15      1
#
# [135 rows x 3 columns]

# %%
lst_every_episode.append((df_nodes1, df_edges1))

# %%
len(lst_every_episode)
# Out:
# 2

# %%
G = nx.Graph()

# Hinzufügen von Knoten zum Graphen
for idx, row in df_nodes.iterrows():
    G.add_node(row['ID'], label=row['name'], size=row['value'], color=row['colour'])

# Hinzufügen von Kanten zum Graphen
for idx, row in df_edges.iterrows():
    G.add_edge(row['source'], row['target'], weight=row['value'])

# %%
print("Knoten und ihre Attribute:")
for node, attrs in G.nodes(data=True):
    print(f"Knoten {node}: {attrs}")

# Ausgabe der Kanten und ihrer Attribute
print("\nKanten und ihre Attribute:")
for source, target, attrs in G.edges(data=True):
    print(f"Kante von {source} nach {target}: {attrs}")
# Out:
# Knoten und ihre Attribute:
# Knoten 0: {'label': 'R2-D2', 'size': 33, 'color': '#bde0f6'}
# Knoten 1: {'label': 'QUI-GON', 'size': 61, 'color': '#4f4fb1'}
# Knoten 2: {'label': 'NUTE GUNRAY', 'size': 19, 'color': '#808080'}
# Knoten 3: {'label': 'PK-4', 'size': 3, 'color': '#808080'}
# Knoten 4: {'label': 'TC-14', 'size': 5, 'color': '#808080'}
# Knoten 5: {'label': 'OBI-WAN', 'size': 34, 'color': '#48D1CC'}
# Knoten 6: {'label': 'DOFINE', 'size': 4, 'color': '#808080'}
# Knoten 7: {'label': 'RUNE', 'size': 11, 'color': '#808080'}
# Knoten 8: {'label': 'TEY HOW', 'size': 5, 'color': '#808080'}
# Knoten 9: {'label': 'EMPEROR', 'size': 14, 'color': '#191970'}
# Knoten 10: {'label': 'CAPTAIN PANAKA', 'size': 20, 'color': '#808080'}
# Knoten 11: {'label': 'SIO BIBBLE', 'size': 8, 'color': '#808080'}
# Knoten 12: {'label': 'JAR JAR', 'size': 36, 'color': '#9a9a00'}
# Knoten 13: {'label': 'TARPALS', 'size': 4, 'color': '#808080'}
# Knoten 14: {'label': 'BOSS NASS', 'size': 5, 'color': '#808080'}
# Knoten 15: {'label': 'PADME', 'size': 31, 'color': '#DDA0DD'}
# Knoten 16: {'label': 'RIC OLIE', 'size': 12, 'color': '#808080'}
# Knoten 17: {'label': 'WATTO', 'size': 8, 'color': '#808080'}
# Knoten 18: {'label': 'ANAKIN', 'size': 41, 'color': '#ce3b59'}
# Knoten 19: {'label': 'SEBULBA', 'size': 4, 'color': '#808080'}
# Knoten 20: {'label': 'JIRA', 'size': 4, 'color': '#808080'}
# Knoten 21: {'label': 'SHMI', 'size': 11, 'color': '#808080'}
# Knoten 22: {'label': 'C-3PO', 'size': 6, 'color': '#FFD700'}
# Knoten 23: {'label': 'DARTH MAUL', 'size': 6, 'color': '#808080'}
# Knoten 24: {'label': 'KITSTER', 'size': 5, 'color': '#808080'}
# Knoten 25: {'label': 'WALD', 'size': 4, 'color': '#808080'}
# Knoten 26: {'label': 'FODE/BEED', 'size': 12, 'color': '#808080'}
# Knoten 27: {'label': 'JABBA', 'size': 4, 'color': '#808080'}
# Knoten 28: {'label': 'GREEDO', 'size': 3, 'color': '#808080'}
# Knoten 29: {'label': 'VALORUM', 'size': 4, 'color': '#808080'}
# Knoten 30: {'label': 'MACE WINDU', 'size': 6, 'color': '#808080'}
# Knoten 31: {'label': 'KI-ADI-MUNDI', 'size': 5, 'color': '#808080'}
# Knoten 32: {'label': 'YODA', 'size': 7, 'color': '#9ACD32'}
# Knoten 33: {'label': 'RABE', 'size': 3, 'color': '#808080'}
# Knoten 34: {'label': 'BAIL ORGANA', 'size': 3, 'color': '#808080'}
# Knoten 35: {'label': 'GENERAL CEEL', 'size': 5, 'color': '#808080'}
# Knoten 36: {'label': 'BRAVO TWO', 'size': 6, 'color': '#808080'}
# Knoten 37: {'label': 'BRAVO THREE', 'size': 4, 'color': '#808080'}
#
# Kanten und ihre Attribute:
# Kante von 0 nach 15: {'weight': 11}
# Kante von 0 nach 1: {'weight': 14}
# Kante von 0 nach 18: {'weight': 16}
# Kante von 0 nach 17: {'weight': 3}
# Kante von 0 nach 22: {'weight': 2}
# Kante von 0 nach 24: {'weight': 2}
# Kante von 1 nach 2: {'weight': 1}
# Kante von 1 nach 4: {'weight': 1}
# Kante von 1 nach 5: {'weight': 26}
# Kante von 1 nach 12: {'weight': 22}
# Kante von 1 nach 14: {'weight': 2}
# Kante von 1 nach 11: {'weight': 2}
# Kante von 1 nach 10: {'weight': 9}
# Kante von 1 nach 15: {'weight': 16}
# Kante von 1 nach 16: {'weight': 2}
# Kante von 1 nach 17: {'weight': 6}
# Kante von 1 nach 18: {'weight': 22}
# Kante von 1 nach 19: {'weight': 2}
# Kante von 1 nach 20: {'weight': 2}
# Kante von 1 nach 21: {'weight': 8}
# Kante von 1 nach 24: {'weight': 2}
# Kante von 1 nach 25: {'weight': 2}
# Kante von 1 nach 22: {'weight': 1}
# Kante von 1 nach 27: {'weight': 1}
# Kante von 1 nach 28: {'weight': 1}
# Kante von 1 nach 9: {'weight': 1}
# Kante von 1 nach 29: {'weight': 1}
# Kante von 1 nach 30: {'weight': 2}
# Kante von 1 nach 31: {'weight': 2}
# Kante von 1 nach 32: {'weight': 2}
# Kante von 1 nach 33: {'weight': 1}
# Kante von 2 nach 4: {'weight': 1}
# Kante von 2 nach 6: {'weight': 1}
# Kante von 2 nach 7: {'weight': 8}
# Kante von 2 nach 8: {'weight': 1}
# Kante von 2 nach 9: {'weight': 5}
# Kante von 2 nach 11: {'weight': 2}
# Kante von 2 nach 23: {'weight': 3}
# Kante von 2 nach 35: {'weight': 1}
# Kante von 2 nach 15: {'weight': 1}
# Kante von 3 nach 4: {'weight': 1}
# Kante von 4 nach 5: {'weight': 1}
# Kante von 4 nach 6: {'weight': 1}
# Kante von 5 nach 12: {'weight': 12}
# Kante von 5 nach 14: {'weight': 2}
# Kante von 5 nach 10: {'weight': 7}
# Kante von 5 nach 16: {'weight': 3}
# Kante von 5 nach 11: {'weight': 1}
# Kante von 5 nach 18: {'weight': 5}
# Kante von 5 nach 21: {'weight': 1}
# Kante von 5 nach 32: {'weight': 3}
# Kante von 5 nach 30: {'weight': 2}
# Kante von 5 nach 31: {'weight': 1}
# Kante von 5 nach 15: {'weight': 1}
# Kante von 6 nach 8: {'weight': 1}
# Kante von 7 nach 8: {'weight': 2}
# Kante von 7 nach 9: {'weight': 3}
# Kante von 7 nach 23: {'weight': 1}
# Kante von 9 nach 10: {'weight': 3}
# Kante von 9 nach 11: {'weight': 1}
# Kante von 9 nach 23: {'weight': 3}
# Kante von 9 nach 29: {'weight': 2}
# Kante von 9 nach 12: {'weight': 2}
# Kante von 9 nach 34: {'weight': 1}
# Kante von 9 nach 35: {'weight': 1}
# Kante von 9 nach 15: {'weight': 1}
# Kante von 10 nach 11: {'weight': 3}
# Kante von 10 nach 12: {'weight': 7}
# Kante von 10 nach 15: {'weight': 7}
# Kante von 10 nach 16: {'weight': 2}
# Kante von 10 nach 18: {'weight': 2}
# Kante von 10 nach 14: {'weight': 1}
# Kante von 11 nach 12: {'weight': 1}
# Kante von 11 nach 15: {'weight': 1}
# Kante von 12 nach 13: {'weight': 2}
# Kante von 12 nach 14: {'weight': 2}
# Kante von 12 nach 16: {'weight': 1}
# Kante von 12 nach 15: {'weight': 9}
# Kante von 12 nach 19: {'weight': 2}
# Kante von 12 nach 18: {'weight': 8}
# Kante von 12 nach 21: {'weight': 3}
# Kante von 12 nach 24: {'weight': 1}
# Kante von 12 nach 25: {'weight': 1}
# Kante von 12 nach 27: {'weight': 1}
# Kante von 12 nach 26: {'weight': 2}
# Kante von 12 nach 29: {'weight': 1}
# Kante von 12 nach 35: {'weight': 1}
# Kante von 14 nach 15: {'weight': 2}
# Kante von 14 nach 18: {'weight': 1}
# Kante von 15 nach 17: {'weight': 3}
# Kante von 15 nach 18: {'weight': 16}
# Kante von 15 nach 19: {'weight': 2}
# Kante von 15 nach 20: {'weight': 1}
# Kante von 15 nach 21: {'weight': 5}
# Kante von 15 nach 22: {'weight': 2}
# Kante von 15 nach 24: {'weight': 1}
# Kante von 15 nach 27: {'weight': 1}
# Kante von 15 nach 26: {'weight': 1}
# Kante von 16 nach 18: {'weight': 4}
# Kante von 16 nach 36: {'weight': 4}
# Kante von 16 nach 37: {'weight': 2}
# Kante von 17 nach 18: {'weight': 4}
# Kante von 17 nach 22: {'weight': 1}
# Kante von 17 nach 24: {'weight': 1}
# Kante von 18 nach 19: {'weight': 2}
# Kante von 18 nach 20: {'weight': 2}
# Kante von 18 nach 21: {'weight': 7}
# Kante von 18 nach 22: {'weight': 3}
# Kante von 18 nach 24: {'weight': 3}
# Kante von 18 nach 25: {'weight': 2}
# Kante von 18 nach 27: {'weight': 1}
# Kante von 18 nach 28: {'weight': 1}
# Kante von 18 nach 30: {'weight': 3}
# Kante von 18 nach 31: {'weight': 2}
# Kante von 18 nach 32: {'weight': 3}
# Kante von 18 nach 33: {'weight': 1}
# Kante von 18 nach 36: {'weight': 2}
# Kante von 18 nach 37: {'weight': 1}
# Kante von 19 nach 21: {'weight': 1}
# Kante von 19 nach 27: {'weight': 1}
# Kante von 21 nach 27: {'weight': 1}
# Kante von 21 nach 24: {'weight': 1}
# Kante von 22 nach 24: {'weight': 1}
# Kante von 23 nach 35: {'weight': 1}
# Kante von 24 nach 25: {'weight': 1}
# Kante von 25 nach 28: {'weight': 1}
# Kante von 26 nach 27: {'weight': 1}
# Kante von 29 nach 34: {'weight': 1}
# Kante von 30 nach 31: {'weight': 3}
# Kante von 30 nach 32: {'weight': 4}
# Kante von 30 nach 33: {'weight': 1}
# Kante von 31 nach 32: {'weight': 3}
# Kante von 31 nach 33: {'weight': 1}
# Kante von 32 nach 33: {'weight': 1}
# Kante von 36 nach 37: {'weight': 2}

# %%
labels = {node: data['label'] for node, data in G.nodes(data=True)}

plt.figure(figsize=(12, 10))

# Netzwerkdiagramm zeichnen
nx.draw(G, 
        labels=labels, 
        with_labels=True, 
        node_size=500, 
        edge_color='black', 
        font_size=10, 
        font_weight='bold',
        # alpha=0.5,
        width=0.5,
        pos=nx.spring_layout(G, k=0.1, iterations=20)
       )

plt.title("One-Mode Netzwerk von Interaktionen der Star Wars Charakteren der Episode 1")
plt.show()

# %%
lst_every_episode = []

for episode in range(1, 8):
    filename = f'data/Star Wars/starwars-episode-{episode}-interactions-allCharacters.json'
    with open(filename, 'r') as file:
        data = json.load(file)

        nodes = data['nodes']

        df_nodes = pd.DataFrame(nodes)
        df_nodes = df_nodes.reset_index(drop=False)
        df_nodes = df_nodes.rename(columns={"index": "ID"})

        edges = data['links']
        df_edges = pd.DataFrame(edges)

        G = nx.Graph()

        for idx, row in df_nodes.iterrows():
            G.add_node(row['ID'], label=row['name'], size=row['value'], color=row['colour'])

        for idx, row in df_edges.iterrows():
            G.add_edge(row['source'], row['target'], weight=row['value'])
        
        lst_every_episode.append(G)

# %%
for episode in lst_every_episode:
    degree_dict = nx.degree(episode)
    name_degree_list = [(episode.nodes[node]['label'], degree) for node, degree in degree_dict]
    print(name_degree_list)
# Out:
# [('R2-D2', 6), ('QUI-GON', 26), ('NUTE GUNRAY', 10), ('PK-4', 1), ('TC-14', 5), ('OBI-WAN', 13), ('DOFINE', 3), ('RUNE', 4), ('TEY HOW', 3), ('EMPEROR', 11), ('CAPTAIN PANAKA', 9), ('SIO BIBBLE', 7), ('JAR JAR', 18), ('TARPALS', 1), ('BOSS NASS', 6), ('PADME', 18), ('RIC OLIE', 7), ('WATTO', 6), ('ANAKIN', 23), ('SEBULBA', 6), ('JIRA', 3), ('SHMI', 8), ('C-3PO', 6), ('DARTH MAUL', 4), ('KITSTER', 9), ('WALD', 5), ('FODE/BEED', 3), ('JABBA', 7), ('GREEDO', 3), ('VALORUM', 4), ('MACE WINDU', 6), ('KI-ADI-MUNDI', 6), ('YODA', 6), ('RABE', 5), ('BAIL ORGANA', 2), ('GENERAL CEEL', 4), ('BRAVO TWO', 3), ('BRAVO THREE', 3)]
# [('R2-D2', 3), ('CAPTAIN TYPHO', 3), ('EMPEROR', 9), ('SENATOR ASK AAK', 7), ('ORN FREE TAA', 3), ('MACE WINDU', 10), ('YODA', 10), ('KI-ADI-MUNDI', 5), ('BAIL ORGANA', 7), ('JAR JAR', 10), ('OBI-WAN', 18), ('ANAKIN', 21), ('PADME', 17), ('PK-4', 1), ('SIO BIBBLE', 1), ('SOLA', 4), ('JOBAL', 4), ('RUWEE', 4), ('TAUN WE', 4), ('LAMA SU', 2), ('BOBA FETT', 3), ('JANGO FETT', 4), ('WATTO', 1), ('C-3PO', 6), ('OWEN', 5), ('BERU', 5), ('CLIEGG', 5), ('SHMI', 1), ('COUNT DOOKU', 10), ('SUN RIT', 6), ('POGGLE', 6), ('NUTE GUNRAY', 6), ('PLO KOON', 1)]
# [('R2-D2', 8), ('ANAKIN', 14), ('OBI-WAN', 13), ('ODD BALL', 2), ('GENERAL GRIEVOUS', 3), ('EMPEROR', 11), ('COUNT DOOKU', 3), ('BAIL ORGANA', 12), ('C-3PO', 9), ('PADME', 10), ('YODA', 9), ('FANG ZAR', 4), ('MON MOTHMA', 4), ('GIDDEAN DANU', 4), ('MACE WINDU', 5), ('CAPTAIN TYPHO', 3), ('CLONE COMMANDER GREE', 1), ('CLONE COMMANDER CODY', 4), ('JAR JAR', 2), ('TION MEDON', 1), ('NUTE GUNRAY', 2), ('PLO KOON', 0), ('CAPTAIN ANTILLES', 3), ('DARTH VADER', 1), ('QUI-GON', 2)]
# [('R2-D2', 9), ('CHEWBACCA', 6), ('C-3PO', 10), ('LUKE', 15), ('DARTH VADER', 4), ('CAMIE', 2), ('BIGGS', 8), ('LEIA', 12), ('BERU', 5), ('OWEN', 4), ('OBI-WAN', 7), ('MOTTI', 3), ('TARKIN', 3), ('HAN', 8), ('GREEDO', 1), ('JABBA', 1), ('DODONNA', 3), ('GOLD LEADER', 5), ('WEDGE', 5), ('RED LEADER', 7), ('RED TEN', 2), ('GOLD FIVE', 0)]
# [('R2-D2', 6), ('CHEWBACCA', 9), ('LUKE', 12), ('HAN', 11), ('RIEEKAN', 4), ('LEIA', 10), ('C-3PO', 10), ('DERLIN', 2), ('OBI-WAN', 3), ('ZEV', 2), ('PIETT', 4), ('OZZEL', 2), ('DARTH VADER', 11), ('DACK', 1), ('WEDGE', 2), ('JANSON', 1), ('NEEDA', 2), ('EMPEROR', 1), ('YODA', 2), ('BOBA FETT', 7), ('LANDO', 8)]
# [('R2-D2', 8), ('CHEWBACCA', 7), ('JERJERROD', 1), ('DARTH VADER', 5), ('C-3PO', 11), ('BIB FORTUNA', 3), ('JABBA', 5), ('LUKE', 15), ('BOUSHH', 4), ('HAN', 9), ('LEIA', 9), ('LANDO', 9), ('EMPEROR', 2), ('YODA', 1), ('OBI-WAN', 1), ('MON MOTHMA', 8), ('ADMIRAL ACKBAR', 7), ('PIETT', 1), ('WEDGE', 2), ('ANAKIN', 2)]
# [('LUKE', 1), ('R2-D2', 3), ('CHEWBACCA', 12), ('BB-8', 12), ('LOR SAN TEKKA', 4), ('POE', 16), ('KYLO REN', 10), ('CAPTAIN PHASMA', 7), ('FINN', 14), ('UNKAR PLUTT', 2), ('REY', 10), ('GENERAL HUX', 5), ('LIEUTENANT MITAKA', 2), ('HAN', 14), ('BALA-TIK', 5), ('SNOKE', 2), ('MAZ', 5), ('C-3PO', 10), ('LEIA', 10), ('SNAP', 8), ('ADMIRAL ACKBAR', 7), ('ADMIRAL STATURA', 7), ('YOLO ZIFF', 4), ('COLONEL DATOO', 1), ('ELLO ASTY', 4), ('JESS', 5), ('NIV LEK', 4)]

# %%
from collections import defaultdict

character_counts = defaultdict(int)

for episode in lst_every_episode:
    degree_dict = nx.degree(episode)
    for node, _ in degree_dict:
        character_name = episode.nodes[node]['label']
        character_counts[character_name] += 1

# Sortieren der Charaktere absteigend nach ihrer Häufigkeit
sorted_character_counts = sorted(character_counts.items(), key=lambda x: x[1], reverse=True)

# Ausgabe der sortierten Häufigkeiten
for character, count in sorted_character_counts:
    print(f"{character}: {count}")
# Out:
# R2-D2: 7
# C-3PO: 7
# OBI-WAN: 6
# EMPEROR: 5
# YODA: 5
# ANAKIN: 4
# DARTH VADER: 4
# CHEWBACCA: 4
# LUKE: 4
# LEIA: 4
# HAN: 4
# NUTE GUNRAY: 3
# JAR JAR: 3
# PADME: 3
# JABBA: 3
# MACE WINDU: 3
# BAIL ORGANA: 3
# WEDGE: 3
# QUI-GON: 2
# PK-4: 2
# SIO BIBBLE: 2
# WATTO: 2
# SHMI: 2
# GREEDO: 2
# KI-ADI-MUNDI: 2
# CAPTAIN TYPHO: 2
# BOBA FETT: 2
# OWEN: 2
# BERU: 2
# COUNT DOOKU: 2
# PLO KOON: 2
# MON MOTHMA: 2
# PIETT: 2
# LANDO: 2
# ADMIRAL ACKBAR: 2
# TC-14: 1
# DOFINE: 1
# RUNE: 1
# TEY HOW: 1
# CAPTAIN PANAKA: 1
# TARPALS: 1
# BOSS NASS: 1
# RIC OLIE: 1
# SEBULBA: 1
# JIRA: 1
# DARTH MAUL: 1
# KITSTER: 1
# WALD: 1
# FODE/BEED: 1
# VALORUM: 1
# RABE: 1
# GENERAL CEEL: 1
# BRAVO TWO: 1
# BRAVO THREE: 1
# SENATOR ASK AAK: 1
# ORN FREE TAA: 1
# SOLA: 1
# JOBAL: 1
# RUWEE: 1
# TAUN WE: 1
# LAMA SU: 1
# JANGO FETT: 1
# CLIEGG: 1
# SUN RIT: 1
# POGGLE: 1
# ODD BALL: 1
# GENERAL GRIEVOUS: 1
# FANG ZAR: 1
# GIDDEAN DANU: 1
# CLONE COMMANDER GREE: 1
# CLONE COMMANDER CODY: 1
# TION MEDON: 1
# CAPTAIN ANTILLES: 1
# CAMIE: 1
# BIGGS: 1
# MOTTI: 1
# TARKIN: 1
# DODONNA: 1
# GOLD LEADER: 1
# RED LEADER: 1
# RED TEN: 1
# GOLD FIVE: 1
# RIEEKAN: 1
# DERLIN: 1
# ZEV: 1
# OZZEL: 1
# DACK: 1
# JANSON: 1
# NEEDA: 1
# JERJERROD: 1
# BIB FORTUNA: 1
# BOUSHH: 1
# BB-8: 1
# LOR SAN TEKKA: 1
# POE: 1
# KYLO REN: 1
# CAPTAIN PHASMA: 1
# FINN: 1
# UNKAR PLUTT: 1
# REY: 1
# GENERAL HUX: 1
# LIEUTENANT MITAKA: 1
# BALA-TIK: 1
# SNOKE: 1
# MAZ: 1
# SNAP: 1
# ADMIRAL STATURA: 1
# YOLO ZIFF: 1
# COLONEL DATOO: 1
# ELLO ASTY: 1
# JESS: 1
# NIV LEK: 1

# %%
r2d2_degrees = []
c3po_degrees = []

for episode in lst_every_episode:
    degree_dict = dict(nx.degree(episode))
    
    for node, degree in degree_dict.items():
        character_name = episode.nodes[node]['label']
        if character_name == "R2-D2":
            r2d2_degrees.append(degree)
        elif character_name == "C-3PO":
            c3po_degrees.append(degree)

# Ausgabe der Listen
print("R2-D2 Degrees:", r2d2_degrees)
print("C-3PO Degrees:", c3po_degrees)
# Out:
# R2-D2 Degrees: [6, 3, 8, 9, 6, 8, 3]
# C-3PO Degrees: [6, 6, 9, 10, 10, 11, 10]
